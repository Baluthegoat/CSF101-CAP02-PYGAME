# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from mlxtend.preprocessing import  minmax_scaling
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
np.random.seed(0)

# %%
# reading the file
df = pd.read_csv('/home/balutheg.o.a.t/Documents/DSF101/top50crypto.csv/Ethereum.csv')

# %%
Converting USD to Ngultrum

# %%
exchange_rate = 83.18
df['Ngultrum'] = (df['Price'] * exchange_rate).round(2)
df
# Out:
#        SNo        Date    Price     Open     High      Low       Vol.  \
# 0        1  2016-03-10    11.75    11.20    11.85    11.07        0.0
# 1        2  2016-03-11    11.95    11.75    11.95    11.75      180.0
# 2        3  2016-03-12    12.92    11.95    13.45    11.95      830.0
# 3        4  2016-03-13    15.07    12.92    15.07    12.92     1300.0
# 4        5  2016-03-14    12.50    15.07    15.07    11.40    92180.0
# ...    ...         ...      ...      ...      ...      ...        ...
# 1989  1990  2021-08-20  3284.21  3184.83  3300.36  3179.18   739320.0
# 1990  1991  2021-08-21  3223.96  3285.12  3307.33  3200.19   768740.0
# 1991  1992  2021-08-22  3238.70  3224.17  3271.94  3128.98   747650.0
# 1992  1993  2021-08-23  3319.49  3238.41  3375.42  3231.96  1090000.0
# 1993  1994  2021-08-24  3329.47  3322.60  3357.99  3283.80   802790.0
#
#       Change %   Ngultrum
# 0         4.91     977.37
# 1         1.70     994.00
# 2         8.12    1074.69
# ...

# %%
Finding missing numbers

# %%
# getting the number of missing data points per column
missing_values_count = df.isnull().sum()
# lokking at the # of missing points in the first 100 columns
missing_values_count[0:100]
# Out:
# SNo         0
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# Ngultrum    0
# dtype: int64

# %%
print(df)
# Out:
#        SNo       Date    Price     Open     High      Low       Vol.  \
# 0        1 2016-03-10    11.75    11.20    11.85    11.07        0.0
# 1        2 2016-03-11    11.95    11.75    11.95    11.75      180.0
# 2        3 2016-03-12    12.92    11.95    13.45    11.95      830.0
# 3        4 2016-03-13    15.07    12.92    15.07    12.92     1300.0
# 4        5 2016-03-14    12.50    15.07    15.07    11.40    92180.0
# ...    ...        ...      ...      ...      ...      ...        ...
# 1989  1990 2021-08-20  3284.21  3184.83  3300.36  3179.18   739320.0
# 1990  1991 2021-08-21  3223.96  3285.12  3307.33  3200.19   768740.0
# 1991  1992 2021-08-22  3238.70  3224.17  3271.94  3128.98   747650.0
# 1992  1993 2021-08-23  3319.49  3238.41  3375.42  3231.96  1090000.0
# 1993  1994 2021-08-24  3329.47  3322.60  3357.99  3283.80   802790.0
#
#       Change %   Ngultrum
# 0         4.91     977.37
# 1         1.70     994.00
# 2         8.12    1074.69
# 3        16.64    1253.52
# ...

# %%
Plotting Graphs

# %%
sns.set()
sns.set_style('whitegrid')
# ploting the 'Price' column from the DataFrame
df['Date'] = pd.to_datetime(df['Date'])
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Price'], label='Price')
plt.xlabel('Date')
plt.ylabel('Price')

start_date_num = date2num(pd.to_datetime(start_date))
end_date_num = date2num(pd.to_datetime(end_date))
# setting the range for the x-axis (date range)
start_date = '2016-03-10'
end_date = '2021-08-24'
#plt.xlim(start_date, end_date)
# Add a legend explicitly
plt.xlim(start_date_num, end_date_num)
plt.legend()

plt.show()
